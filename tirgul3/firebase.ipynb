# %% [markdown]
# <a href="https://colab.research.google.com/github/AshrfCode/Anan-Tirgulem/blob/main/tirgul3/firebase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install firebase
# Out:
# Collecting firebase
#   Downloading firebase-4.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from firebase) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->firebase) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->firebase) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->firebase) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->firebase) (2026.2.25)
# Downloading firebase-4.0.1-py3-none-any.whl (12 kB)
# Installing collected packages: firebase
# Successfully installed firebase-4.0.1

# %%
from firebase import firebase

FBconn = firebase.FirebaseApplication(
    'https://first-firebase-738a0-default-rtdb.firebaseio.com/',
    None
)

# %%
temp = int(input("Enter temperature: "))

data_to_upload = {
    "Temp": temp
}

result = FBconn.post('/myTest1/', data_to_upload)
print(result)

# %%
res = FBconn.get('/myTest1/', None)
print(res)
# Out:
# {'-OqCpdiv9wUwW_dqgEmZ': {'Temp': 3}}

# %%
temp = int(input("Enter temperature: "))

data_to_upload = {
    "Temp": temp
}

result = FBconn.post('/myTest1/', data_to_upload)
print(result)
# Out:
# Enter temperature: 1
# {'name': '-OqCrBY29MRT-5Hs-Gdx'}

# %%
res = FBconn.get('/myTest1/', None)

if res:
    for key, value in res.items():
        print("ID:", key, "Data:", value)
else:
    print("No records")

# %%
def add_temperature(temp):
    data = {"Temp": temp}
    return FBconn.post('/myTest1/', data)

def get_all_records():
    return FBconn.get('/myTest1/', None)

def update_temperature(record_id, new_temp):
    return FBconn.put('/myTest1/' + record_id, 'Temp', new_temp)

def delete_record(record_id):
    return FBconn.delete('/myTest1/', record_id)

def display_records():
    records = get_all_records()
    if records:
        print("\nCurrent Records:")
        for record_id, data in records.items():
            print(f"ID: {record_id} - Temperature: {data['Temp']}°C")
    else:
        print("\nNo records found")

# %%
while True:
    print("\nTemperature Tracker Menu:")
    print("1. Add new temperature")
    print("2. Update existing temperature")
    print("3. Delete temperature record")
    print("4. View all records")
    print("5. Exit")

    choice = input("Enter your choice (1-5): ")

    if choice == "1":
        temp = int(input("Enter temperature: "))
        add_temperature(temp)
        print("Temperature added")

    elif choice == "2":
        display_records()
        record_id = input("Enter record ID to update: ")
        new_temp = int(input("Enter new temperature: "))
        update_temperature(record_id, new_temp)
        print("Temperature updated")

    elif choice == "3":
        display_records()
        record_id = input("Enter record ID to delete: ")
        delete_record(record_id)
        print("Record deleted")

    elif choice == "4":
        display_records()

    elif choice == "5":
        print("Goodbye")
        break

    else:
        print("Invalid choice")
